# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandre858/DataMinig/blob/main/projet_clem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
import seaborn as sns
import os
import tensorflow as tf
from tensorflow import keras as ks
import json



df = pd.read_csv("Data/pokemon.csv")
df.shape

df.head()
# Out:
#          Name  Type1   Type2
# 0   bulbasaur  Grass  Poison
# 1     ivysaur  Grass  Poison
# 2    venusaur  Grass  Poison
# 3  charmander   Fire     NaN
# 4  charmeleon   Fire     NaN

# %%
df2 = df.sort_values(by=['Name'], ascending=True).reset_index(drop=True)
df2.head()
# Out:
#               Name    Type1  Type2
# 0        abomasnow    Grass    Ice
# 1             abra  Psychic    NaN
# 2            absol     Dark    NaN
# 3         accelgor      Bug    NaN
# 4  aegislash-blade    Steel  Ghost

# %%
type1 = df['Type1'].tolist()
type2 = df['Type2'].tolist()

typo = type1 + type2

plt.figure(figsize=(14, 6))

sns.countplot(x=typo)
plt.title('Types of pokemon')
plt.show()

# %%
i = 1


donnees={}


for index,  row in df.iterrows():
  i = i+1
  name = row["Name"]
  type1 = row["Type1"]
  if row["Type2"] != "NaN":
    type2 = row["Type2"]  
  if row["Type2"] df.isna():
    type2 = "pas de second type"
   
    
  
  donnees[i-1] = {"name":name, "type1":type1, "type2":type2}


with open("Data/data.json","w") as file:
  json.dump(donnees, file,indent = 6)
# Out:
#   File "<ipython-input-36-92ac288f112d>", line 13
#     if row["Type2"] isna():
#                        ^
# SyntaxError: invalid syntax
